# %%
## Import packages
# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# encoders
from category_encoders import OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

#metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, roc_auc_score

#pipeline
from sklearn.pipeline import make_pipeline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### I wrangle the data

# %%
# absolute path
df = pd.read_csv('/Users/sisichen/Desktop/Unit2-sprint3-ds25/data/burritos/burritos.csv')

# %%
# relative path
df = pd.read_csv('../data/burritos/burritos.csv', parse_dates=['Date'], index_col='Date')

# %%
df.head()
# Out:
#                         Location      Burrito Neighborhood  \
# Date
# 2016-01-18    Donato's taco shop  California       Miramar
# 2016-01-24  Oscar's Mexican food  California    San Marcos
# 2016-01-24  Oscar's Mexican food     Carnitas          NaN
# 2016-01-24  Oscar's Mexican food  Carne asada          NaN
# 2016-01-27          Pollos Maria   California     Carlsbad
#
#                              Address  \
# Date
# 2016-01-18           6780 Miramar Rd
# 2016-01-24  225 S Rancho Santa Fe Rd
# 2016-01-24                       NaN
# 2016-01-24                       NaN
# 2016-01-27           3055 Harding St
#
#                                                           URL  Yelp  Google  \
# Date
# 2016-01-18                        http://donatostacoshop.net/   3.5     4.2
# 2016-01-24  http://www.yelp.com/biz/oscars-mexican-food-sa...   3.5     3.3
# 2016-01-24                                                NaN   NaN     NaN
# 2016-01-24                                                NaN   NaN     NaN
# 2016-01-27                            http://pollosmaria.com/   4.0     3.8
#
#            Chips  Cost  Hunger  ...  Nopales  Lobster  Queso  Egg  Mushroom  \
# Date                            ...
# 2016-01-18   NaN  6.49     3.0  ...      NaN      NaN    NaN  NaN       NaN
# 2016-01-24   NaN  5.45     3.5  ...      NaN      NaN    NaN  NaN       NaN
# 2016-01-24   NaN  4.85     1.5  ...      NaN      NaN    NaN  NaN       NaN
# 2016-01-24   NaN  5.25     2.0  ...      NaN      NaN    NaN  NaN       NaN
# 2016-01-27     x  6.59     4.0  ...      NaN      NaN    NaN  NaN       NaN
#
#             Bacon  Sushi  Avocado  Corn  Zucchini
# Date
# 2016-01-18    NaN    NaN      NaN   NaN       NaN
# 2016-01-24    NaN    NaN      NaN   NaN       NaN
# 2016-01-24    NaN    NaN      NaN   NaN       NaN
# 2016-01-24    NaN    NaN      NaN   NaN       NaN
# 2016-01-27    NaN    NaN      NaN   NaN       NaN
#
# [5 rows x 65 columns]

# %%
df['great'] = (df['overall'] > 4)*1

# %%
df.isnull().sum()/len(df)
# Out:
# Location        0.000000
# Burrito         0.000000
# Neighborhood    0.782506
# Address         0.791962
# URL             0.794326
#                   ...
# Bacon           0.992908
# Sushi           0.995272
# Avocado         0.969267
# Corn            0.992908
# Zucchini        0.997636
# Length: 65, dtype: float64

# %%
na_cols = df.columns[df.isnull().mean()>0.5]

# %%
df.drop(columns=na_cols, inplace=True)

# %%
df.head()
# Out:
#                         Location      Burrito  Cost  Hunger  Tortilla  Temp  \
# Date
# 2016-01-18    Donato's taco shop  California   6.49     3.0       3.0   5.0
# 2016-01-24  Oscar's Mexican food  California   5.45     3.5       2.0   3.5
# 2016-01-24  Oscar's Mexican food     Carnitas  4.85     1.5       3.0   2.0
# 2016-01-24  Oscar's Mexican food  Carne asada  5.25     2.0       3.0   2.0
# 2016-01-27          Pollos Maria   California  6.59     4.0       4.0   5.0
#
#             Meat  Fillings  Meat:filling  Uniformity  Salsa  Synergy  Wrap  \
# Date
# 2016-01-18   3.0       3.5           4.0         4.0    4.0      4.0   4.0
# 2016-01-24   2.5       2.5           2.0         4.0    3.5      2.5   5.0
# 2016-01-24   2.5       3.0           4.5         4.0    3.0      3.0   5.0
# 2016-01-24   3.5       3.0           4.0         5.0    4.0      4.0   5.0
# 2016-01-27   4.0       3.5           4.5         5.0    2.5      4.5   4.0
#
#             overall Reviewer  great
# Date
# 2016-01-18     3.80    Scott      0
# 2016-01-24     3.00    Scott      0
# 2016-01-24     3.00    Emily      0
# 2016-01-24     3.75  Ricardo      0
# 2016-01-27     4.20    Scott      1

# %%
cat_cols = df.select_dtypes(include='object').columns

# %%
df.drop(columns=cat_cols, inplace=True)

# %%
df
# Out:
#             Cost  Hunger  Tortilla  Temp  Meat  Fillings  Meat:filling  \
# Date
# 2016-01-18  6.49     3.0       3.0   5.0   3.0       3.5           4.0
# 2016-01-24  5.45     3.5       2.0   3.5   2.5       2.5           2.0
# 2016-01-24  4.85     1.5       3.0   2.0   2.5       3.0           4.5
# 2016-01-24  5.25     2.0       3.0   2.0   3.5       3.0           4.0
# 2016-01-27  6.59     4.0       4.0   5.0   4.0       3.5           4.5
# ...          ...     ...       ...   ...   ...       ...           ...
# 2019-08-27  6.00     1.0       5.0   4.0   3.5       NaN           4.0
# 2019-08-27  6.00     4.0       4.0   5.0   NaN       3.5           4.0
# 2019-08-27  7.90     3.0       4.0   4.0   4.0       3.7           3.0
# 2019-08-27  7.90     3.0       5.0   2.0   5.0       5.0           5.0
# 2019-08-27  5.50     3.5       3.0   5.0   4.3       4.0           4.9
#
#             Uniformity  Salsa  Synergy  Wrap  overall  great
# Date
# 2016-01-18         4.0    4.0      4.0   4.0     3.80      0
# 2016-01-24         4.0    3.5      2.5   5.0     3.00      0
# 2016-01-24         4.0    3.0      3.0   5.0     3.00      0
# 2016-01-24         5.0    4.0      4.0   5.0     3.75      0
# 2016-01-27         5.0    2.5      4.5   4.0     4.20      1
# ...                ...    ...      ...   ...      ...    ...
# 2019-08-27         4.0    2.0      2.0   5.0     3.50      0
# 2019-08-27         4.0    5.0      4.0   3.0     4.00      0
# 2019-08-27         2.0    3.5      4.0   4.5     3.50      0
# 2019-08-27         2.0    5.0      5.0   2.0     4.00      0
# 2019-08-27         3.8    3.0      4.5   4.0     4.60      1
#
# [423 rows x 13 columns]

# %%
## create wrangle function
def wrangle(data_path):
    df = pd.read_csv(data_path, parse_dates=['Date'], index_col='Date')
    
    df['great'] = (df['overall'] > 4)*1
    
    na_cols = df.columns[df.isnull().mean()>0.5]
    
    df.drop(columns=na_cols, inplace=True)
    
    cat_cols = df.select_dtypes(include='object').columns
    # high_car = [col for col in cat_cols if df[col].nunique()> cutoff]
    df.drop(columns=cat_cols, inplace=True)
    
    df.drop(columns='overall',inplace=True)
    
    return df

# %%
data_path = '../data/burritos/burritos.csv'
df = wrangle(data_path)

# %%
df
# Out:
#             Cost  Hunger  Length  Circum  Volume  Tortilla  Temp  Meat  \
# Date
# 2016-01-18  6.49     3.0     NaN     NaN     NaN       3.0   5.0   3.0
# 2016-01-24  5.45     3.5     NaN     NaN     NaN       2.0   3.5   2.5
# 2016-01-24  4.85     1.5     NaN     NaN     NaN       3.0   2.0   2.5
# 2016-01-24  5.25     2.0     NaN     NaN     NaN       3.0   2.0   3.5
# 2016-01-27  6.59     4.0     NaN     NaN     NaN       4.0   5.0   4.0
# ...          ...     ...     ...     ...     ...       ...   ...   ...
# 2019-08-27  6.00     1.0    17.0    20.5    0.57       5.0   4.0   3.5
# 2019-08-27  6.00     4.0    19.0    26.0    1.02       4.0   5.0   NaN
# 2019-08-27  7.90     3.0    20.0    22.0    0.77       4.0   4.0   4.0
# 2019-08-27  7.90     3.0    22.5    24.5    1.07       5.0   2.0   5.0
# 2019-08-27  5.50     3.5    17.0    21.3    0.61       3.0   5.0   4.3
#
#             Fillings  Meat:filling  Uniformity  Salsa  Synergy  Wrap  great
# Date
# 2016-01-18       3.5           4.0         4.0    4.0      4.0   4.0      0
# 2016-01-24       2.5           2.0         4.0    3.5      2.5   5.0      0
# 2016-01-24       3.0           4.5         4.0    3.0      3.0   5.0      0
# 2016-01-24       3.0           4.0         5.0    4.0      4.0   5.0      0
# 2016-01-27       3.5           4.5         5.0    2.5      4.5   4.0      1
# ...              ...           ...         ...    ...      ...   ...    ...
# 2019-08-27       NaN           4.0         4.0    2.0      2.0   5.0      0
# 2019-08-27       3.5           4.0         4.0    5.0      4.0   3.0      0
# 2019-08-27       3.7           3.0         2.0    3.5      4.0   4.5      0
# 2019-08-27       5.0           5.0         2.0    5.0      5.0   2.0      0
# 2019-08-27       4.0           4.9         3.8    3.0      4.5   4.0      1
#
# [423 rows x 15 columns]

# %%
df = df.sort_index()

# %%
df
# Out:
#             Cost  Hunger  Length  Circum  Volume  Tortilla  Temp  Meat  \
# Date
# 2011-05-16  8.00     4.0     NaN     NaN     NaN       3.0   NaN   2.0
# 2015-04-20   NaN     4.0     NaN     NaN     NaN       5.0   NaN   5.0
# 2016-01-18  6.49     3.0     NaN     NaN     NaN       3.0   5.0   3.0
# 2016-01-24  5.25     2.0     NaN     NaN     NaN       3.0   2.0   3.5
# 2016-01-24  4.85     1.5     NaN     NaN     NaN       3.0   2.0   2.5
# ...          ...     ...     ...     ...     ...       ...   ...   ...
# 2019-08-27  6.75     3.0   19.00    25.0    0.94       3.0   4.0   4.0
# 2019-08-27  5.50     2.0   19.00    23.0    0.80       4.5   5.0   5.0
# 2019-08-27  6.00     3.0   17.50    21.5    0.64       4.0   4.0   4.5
# 2019-08-27  5.50     3.5   17.00    21.3    0.61       3.0   5.0   4.3
# 2026-04-25  8.00     4.0   21.59     NaN     NaN       4.5   5.0   5.0
#
#             Fillings  Meat:filling  Uniformity  Salsa  Synergy  Wrap  great
# Date
# 2011-05-16       3.0           2.0         3.0    2.0      3.0   2.0      0
# 2015-04-20       5.0           5.0         4.0    5.0      5.0   5.0      1
# 2016-01-18       3.5           4.0         4.0    4.0      4.0   4.0      0
# 2016-01-24       3.0           4.0         5.0    4.0      4.0   5.0      0
# 2016-01-24       3.0           4.5         4.0    3.0      3.0   5.0      0
# ...              ...           ...         ...    ...      ...   ...    ...
# 2019-08-27       3.0           4.0         4.0    3.0      3.0   5.0      0
# 2019-08-27       3.5           4.0         4.5    4.0      4.9   4.5      1
# 2019-08-27       4.0           3.0         3.0    4.5      4.0   4.5      0
# 2019-08-27       4.0           4.9         3.8    3.0      4.5   4.0      1
# 2026-04-25       5.0           4.5         5.0    3.0      5.0   5.0      1
#
# [423 rows x 15 columns]

# %% [markdown]
# ### II.split the data

# %%
X = df.drop(columns='great')
y = df['great']

# %%
## Ven
cutoff1 = '2009-01-01'
cutoff2 = '2017-07-01'
X_train = X[(X.index > cutoff1) & ( X.index < cutoff2)]
y_train = y[(X.index > cutoff1) & ( X.index < cutoff2)]

# %%
cutoff1 = int(0.6*len(df))
cutoff2 = int(0.8*len(df))

# %%
X_train, y_train = X.iloc[:cutoff1], y.iloc[:cutoff1]
X_val, y_val = X.iloc[cutoff1:cutoff2], y.iloc[cutoff1:cutoff2]
X_test, y_test = X.iloc[cutoff2:], y.iloc[cutoff2:]

# %% [markdown]
# ### III.Establish the baseline

# %%
y_train.value_counts()
# Out:
# 0    195
# 1     58
# Name: great, dtype: int64

# %%
# Baseline accuracy
print(accuracy_score(y_train, [0]*len(y_train)))
# Out:
# 0.7707509881422925

# %%
print(y_train.value_counts(normalize=True).max())
# Out:
# 0.7707509881422925

# %% [markdown]
# ### IV. Build the model

# %%
model_rf = make_pipeline(OrdinalEncoder(), 
                         SimpleImputer(), 
                         RandomForestClassifier())

# %%
model_rf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder(cols=[], mapping=[])),
#                 ('simpleimputer', SimpleImputer()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %% [markdown]
# ### V. check the metrics

# %%
print("train acc", accuracy_score(y_train, model_rf.predict(X_train)))
print("val acc", accuracy_score(y_val, model_rf.predict(X_val)))
print("test acc", accuracy_score(y_test, model_rf.predict(X_test)))
# Out:
# train acc 1.0
# val acc 0.8823529411764706
# test acc 0.8470588235294118

# %%
# imbalanced data
y_actual = [1, 0, 0, 0, 0, 0, 0, 0]
y_pred = [0, 0, 0, 0, 0, 0 ,0, 0]

# %%
accuracy_score(y_actual, y_pred)
# Out:
# 0.875

# %%
# confusion matrix
# classification report 
# f1 score
# PR curve and PR score

# %%
from sklearn.metrics import roc_curve
fpr, tpr, threshold = roc_curve(y_val,model_rf.predict_proba(X_val)[:,-1])

# %%
pd.DataFrame({'threshold': threshold, 'fpr': fpr, 'tpr': tpr})
# Out:
#     threshold       fpr   tpr
# 0        1.95  0.000000  0.00
# 1        0.95  0.000000  0.04
# 2        0.85  0.000000  0.20
# 3        0.76  0.000000  0.36
# 4        0.65  0.000000  0.52
# 5        0.61  0.000000  0.60
# 6        0.59  0.000000  0.64
# 7        0.58  0.016667  0.68
# 8        0.38  0.100000  0.68
# 9        0.36  0.100000  0.76
# 10       0.31  0.133333  0.76
# 11       0.30  0.133333  0.80
# 12       0.28  0.150000  0.84
# 13       0.25  0.183333  0.84
# 14       0.20  0.250000  0.84
# 15       0.19  0.266667  0.84
# 16       0.18  0.266667  0.88
# 17       0.16  0.283333  0.88
# 18       0.14  0.316667  0.92
# 19       0.12  0.333333  0.92
# 20       0.10  0.366667  0.96
# 21       0.09  0.366667  1.00
# 22       0.05  0.500000  1.00
# 23       0.04  0.566667  1.00
# 24       0.03  0.683333  1.00
# 25       0.02  0.816667  1.00
# 26       0.01  0.916667  1.00
# 27       0.00  1.000000  1.00
